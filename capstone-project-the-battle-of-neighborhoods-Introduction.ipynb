# %% [markdown]
# # Introduction/Business Problem

# %% [markdown]
# ### Toronto is the fastest growing city in Canada, and it is one of the most famous destination for immigrants. Hence, here we will be looking to open a restaurant in Toronto.

# %% [markdown]
# As Toronto has residents from all over the world, which keeps on increasing as this city provides the best job opportunities along with several other facilities. People who migrated or migrating to Canada, has the Toronto as the first option in their mind to work and settle.
#
# As per wikipedia: the diverse population of Toronto reflects its current and historical role as an important destination for immigrants to Canada. More than 50 percent of residents belong to a visible minority population group, and over 200 distinct ethnic origins are represented among its inhabitants. While the majority of Torontonians speak English as their primary language, over 160 languages are spoken in the city.

# %% [markdown]
# ### Problem

# %% [markdown]
# With the increasing diversity in the city, the demand for good Restaurants will always be there. So, in this report, we will try to find out the best possible areas (part of the city) based on the density of restaurants and popularity of the cuisines.

# %% [markdown]
# Example: People looking for doing business in this field, e.g. planning to open restaurant can find this report helpful.
